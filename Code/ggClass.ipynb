# %% [markdown]
# # Import GOGREEN class

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

import numpy as np
import matplotlib.pyplot as plt

# %run GOGREEN.py
# Out:
# /tmp/ipykernel_4300/2042829233.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # Function Definitions

# %%
def ABmag(fluxValues, zeroPoint):
    return (-2.5)*np.log10(fluxValues) + zeroPoint

# %% [markdown]
# # Create instance of GOGREEN class

# %%
path = '/home/astrobits/school/research/data/'
gg = GOGREEN(path)

# %% [markdown]
# # Get Catalogs

# %%
# Description of get() function parameters and return value 
print(gg.get.__annotations__)

allCatalogs = gg.get('all')
# Out:
# {'cat': <class 'str'>}

# %% [markdown]
# ## Clusters.fits

# %%
# cluster_cat = allCatalogs[0]
cluster_cat = gg.get()
cluster_cat
# Out:
#        cluster                   fullname  cluster_id     RA_Best   DEC_Best  \
# 0   COSMOS-125  COSMOS-125                         14  150.620804   2.167500
# 1   COSMOS-221  COSMOS-221                         14  150.561996   2.503100
# 2   COSMOS-28   COSMOS-28                          14  149.469193   1.668500
# 3   COSMOS-63   COSMOS-63                          14  150.358994   1.935200
# 4   SPT0205     SPT-CL J0205-5829                   1   31.451000 -58.480301
# 5   SPT0546     SPT-CL J0546-5345                   2   86.640297 -53.761002
# 6   SPT2106     SPT-CL J2106-5844                   3  316.519104 -58.741100
# 7   SXDF49      SXDF49XGG                          13   34.499599  -5.064900
# 8   SXDF64      SXDF64XGG                          13   34.331902  -5.206700
# 9   SXDF76      SXDF76XGG                          13   34.746101  -5.304100
# 10  SXDF76b     SXDF76bXGG                         13   34.747398  -5.323500
# ...

# %% [markdown]
# ## Photo.fits

# %%
photo_cat = allCatalogs[1]
photo_cat
# Out:
#            Cluster    cPHOTID  SPECID          ra        dec  zspec  \
# 0          SPT0205  101000254      -1   31.576448 -58.548923    NaN
# 1          SPT0205  101000272      -1   31.449797 -58.548134    NaN
# 2          SPT0205  101000286      -1   31.382263 -58.548920    NaN
# 3          SPT0205  101000290      -1   31.419193 -58.548588    NaN
# 4          SPT0205  101000293      -1   31.528271 -58.548615    NaN
# ...            ...        ...     ...         ...        ...    ...
# 274987  SpARCS1613  219005807      -1  243.386673  56.895893    NaN
# 274988  SpARCS1613  219005808      -1  243.300598  56.903133    NaN
# 274989  SpARCS1613  219005809      -1  243.459473  56.902355    NaN
# 274990  SpARCS1613  219005810      -1  243.164047  56.906891    NaN
# 274991  SpARCS1613  219005811      -1  243.487106  56.903622    NaN
#
#         Redshift_Quality   zphot  zphot_l68  zphot_u68  ...  eIA767_tot  \
# 0                    NaN  0.6916      0.653      0.735  ...         NaN
# ...

# %% [markdown]
# ## Redshift_catalogue.fits

# %%
redshift_cat = allCatalogs[2]
redshift_cat
# Out:
#          Cluster     SPECID   RA(J2000)  DEC(J2000)  OBJClass  Redshift  \
# 0     COSMOS-125  114080478  150.605179    2.118631         1   1.41478
# 1     COSMOS-125  114080570  150.594482    2.120006         1   1.34553
# 2     COSMOS-125  114081196  150.587677    2.128183         3   0.96172
# 3     COSMOS-125  114081258  150.596909    2.129453         1   0.72447
# 4     COSMOS-125  114081508  150.609695    2.134149         1   1.13177
# ...          ...        ...         ...         ...       ...       ...
# 2766  SpARCS1613  219050847  243.223846   56.825348         4   0.85000
# 2767  SpARCS1613  219050889  243.242218   56.827805         4   0.86300
# 2768  SpARCS1613  219050903  243.308792   56.829575         4   0.86400
# 2769  SpARCS1613  219050915  243.365891   56.831284         4   0.72100
# 2770  SpARCS1613  219050953  243.244308   56.831821         4   0.87300
#
#       Redshift_Quality  EXTVER  Spec_Flag  SNR_8500_VAR  ...  EWOII_model  \
# ...

# %% [markdown]
# ## Structural paramater catalogs require initialization!!
# These catalogs are seperated into different .fits files, one for each of the 11 included GOGREEN clusters.
# $\newline$
# You must specify the cluster of interest first.

# %% [markdown]
# ## GALFIT_ORG_CATS

# %%
targetCluster = 'SPT2106'

print(gg.loadStruct.__annotations__)
gg.loadStruct(targetCluster, cat="galfit")

galfitSPT2106 = gg.get('galfit')
galfitSPT2106
# Out:
# {'targetCluster': <class 'str'>, 'cat': <class 'str'>}
#      GALAPAGOS_VERSION  GALA_ID    X_IMAGE    Y_IMAGE  ALPHA_J2000  \
# 0     GALAPAGOS-v2.3.0        1  3802.6372   687.7043   316.464658
# 1     GALAPAGOS-v2.3.0        2  2581.7920   371.7912   316.503882
# 2     GALAPAGOS-v2.3.0        3   422.7922   118.3187   316.573268
# 3     GALAPAGOS-v2.3.0        4   626.4250    73.2510   316.566725
# 4     GALAPAGOS-v2.3.0        5   668.0612    76.4480   316.565387
# ...                ...      ...        ...        ...          ...
# 3645  GALAPAGOS-v2.3.0     3646  1759.2758  1966.6211   316.530305
# 3646  GALAPAGOS-v2.3.0     3647  1964.3090  2001.8502   316.523722
# 3647  GALAPAGOS-v2.3.0     3648   724.4913  2249.6641   316.563527
# 3648  GALAPAGOS-v2.3.0     3649  2627.6538  2000.1134   316.502422
# 3649  GALAPAGOS-v2.3.0     3650  3780.3625  2625.2375   316.465424
#
#       DELTA_J2000  MAG_AUTO  MAGERR_AUTO  CLASS_STAR  SKY_GALA_BAND  ...  \
# ...

# %% [markdown]
# ## STRUCT_MATCHED

# %%
matchedSPT2106 = gg.loadStruct(targetCluster)
matchedSPT2106
# Out:
#       PHOTCATID  HSTFOV_flag  Fit_flag   mag  mag_err    re  re_err     n  \
# 0             1            0         0 -99.0    -99.0 -99.0   -99.0 -99.0
# 1             2            0         0 -99.0    -99.0 -99.0   -99.0 -99.0
# 2             3            0         0 -99.0    -99.0 -99.0   -99.0 -99.0
# 3             4            0         0 -99.0    -99.0 -99.0   -99.0 -99.0
# 4             5            0         0 -99.0    -99.0 -99.0   -99.0 -99.0
# ...         ...          ...       ...   ...      ...   ...     ...   ...
# 2918       2919            0         0 -99.0    -99.0 -99.0   -99.0 -99.0
# 2919       2920            0         0 -99.0    -99.0 -99.0   -99.0 -99.0
# 2920       2921            0         0 -99.0    -99.0 -99.0   -99.0 -99.0
# 2921       2922            0         0 -99.0    -99.0 -99.0   -99.0 -99.0
# 2922       2923            0         0 -99.0    -99.0 -99.0   -99.0 -99.0
#
#       n_err     q  q_err    pa  pa_err  dist  hst_id  chi2nu  S/N
# ...

# %% [markdown]
# ### Histogram of K-band magnitudes

# %%
targetCatalog = 'photo'
targetCluster = 'SPT2106'
targetProperty = 'Ks_tot'
criteria = [
    'Star==0',
    'K_flag==0',
    'totmask==0'
]

kFlux = gg.search(targetCluster, targetProperty, criteria, targetCatalog).values
kMag = ABmag(kFlux[kFlux > 0], 25)

# Plot the histogram
fig = plt.figure()
plt.hist(kMag, bins=50, color='k')
plt.title('SPT2106 K-band Magnitude Histogram')
plt.xlabel('Magnitude (AB)')
plt.ylabel('N')
plt.show()

# %% [markdown]
# ### SPT2106 stellar mass vs $r_{\rm e}$

# %%
targetCatalogs = ['photo', 'matched']
targetCluster = 'SPT2106'
targetProperties = [['cPHOTID', 'Mstellar'],['PHOTCATID', 're']]
clusterZ = 1.1306

criteria = [
    'Star==0',
    'K_flag==0',
    'totmask==0',
    '(' + str(clusterZ-0.02) +  '< zspec.values <' + str(clusterZ+0.02) + ')',
    '(' + str(clusterZ-0.08) +  '< zphot.values <' + str(clusterZ+0.08) + ')'
]

mass_zspec = gg.search(targetCluster, targetProperties[0], criteria[:4], targetCatalogs[0])
mass_zphot = gg.search(targetCluster, targetProperties[0], criteria[:3] + criteria[-1:], targetCatalogs[0])

re = gg.search(targetCluster, targetProperties[1], ['re > 0'], targetCatalogs[1])

mass_zspec_re = gg.merge(mass_zspec, re)
mass_zphot_re = gg.merge(mass_zphot, re).query('~cPHOTID.isin(@mass_zspec_re.cPHOTID)')


# Plot K-band mag vs re
fig = plt.figure()
plt.scatter(np.log10(mass_zspec_re.Mstellar.values), mass_zspec_re.re.values, c='orange', label='Spectroscopic z +- 0.02 cluster z')
plt.scatter(np.log10(mass_zphot_re.Mstellar.values), mass_zphot_re.re.values, c='brown', label='Photometric z +- 0.08 cluster z')
plt.title('SPT2016 Stellar Mass vs Effective Radius')
plt.xlabel('log(Stellar Mass/Msun)')
plt.ylabel('Effective Radius (arcsec)')
plt.legend(fontsize='large')
plt.show()

# %% [markdown]
# ### All Clusters Stellar Mass vs $r_{\rm e}$

# %%
targetCatalogs = ['photo', 'matched']
targetProperties = [['cPHOTID', 'Mstellar'],['PHOTCATID', 're']]

fig, ax = plt.subplots(3, 4, figsize=(10,7))
fig.tight_layout()

# SPJ0035
clusterZ = 1.33500
criteria = [
    'Star==0',
    'K_flag==0',
    'totmask==0',
    '(' + str(clusterZ-0.02) +  '< zspec.values <' + str(clusterZ+0.02) + ')',
    '(' + str(clusterZ-0.08) +  '< zphot.values <' + str(clusterZ+0.08) + ')'
]

zspec0035 = gg.search('SpARCS0035', targetProperties[0], criteria[:4], targetCatalogs[0])
print(zspec0035)
zphot0035 = gg.search('SpARCS0035', targetProperties[0], criteria[:3] + criteria[-1:], targetCatalogs[0])
re0035 = gg.search('SPJ0035', targetProperties[1], ['re > 0'], targetCatalogs[1])
print(re0035)
mass_zspec_re0035 = gg.merge(zspec0035, re0035)
mass_zphot_re0035 = gg.merge(zphot0035, re0035).query('~cPHOTID.isin(@mass_zspec_re0035.cPHOTID)')

# GG.MERGE() IS NOT WORKING CORRECTLY. THERE ARE DIFFERENT CONVERSIONS BETWEEN PHOTCATID and cPHOTID

ax[0,0].scatter(np.log10(mass_zspec_re0035.Mstellar.values), mass_zspec_re0035.re.values, c='red', label='Spectroscopic z')
ax[0,0].scatter(np.log10(mass_zphot_re0035.Mstellar.values), mass_zphot_re0035.re.values, c='blue', label='Photometric z')
ax[0,0].title.set_text('SPT2016')

# SPJ0219
clusterZ = 1.32500
criteria = [
    'Star==0',
    'K_flag==0',
    'totmask==0',
    '(' + str(clusterZ-0.02) +  '< zspec.values <' + str(clusterZ+0.02) + ')',
    '(' + str(clusterZ-0.08) +  '< zphot.values <' + str(clusterZ+0.08) + ')'
]

zspec0219 = gg.search('SpARCS0219', targetProperties[0], criteria[:4], targetCatalogs[0])
zphot0219 = gg.search('SpARCS0219', targetProperties[0], criteria[:3] + criteria[-1:], targetCatalogs[0])
re0219 = gg.search('SPJ0219', targetProperties[1], ['re > 0'], targetCatalogs[1])
mass_zspec_re0219 = gg.merge(zspec0219, re0219)
mass_zphot_re0219 = gg.merge(zspec0219, re0219).query('~cPHOTID.isin(@mass_zspec_re0219.cPHOTID)')

ax[0,1].scatter(np.log10(mass_zspec_re0219.Mstellar.values), mass_zspec_re0219.re.values, c='red', label='Spectroscopic z')
ax[0,1].scatter(np.log10(mass_zphot_re0219.Mstellar.values), mass_zphot_re0219.re.values, c='blue', label='Photometric z')
ax[0,1].title.set_text('SPJ0219')

# SPJ0335
clusterZ = 1.36800
criteria = [
    'Star==0',
    'K_flag==0',
    'totmask==0',
    '(' + str(clusterZ-0.02) +  '< zspec.values <' + str(clusterZ+0.02) + ')',
    '(' + str(clusterZ-0.08) +  '< zphot.values <' + str(clusterZ+0.08) + ')'
]

zspec0335 = gg.search('SpARCS0335', targetProperties[0], criteria[:4], targetCatalogs[0])
zphot0335 = gg.search('SpARCS0335', targetProperties[0], criteria[:3] + criteria[-1:], targetCatalogs[0])
re0335 = gg.search('SPJ0335', targetProperties[1], ['re > 0'], targetCatalogs[1])
mass_zspec_re0335 = gg.merge(zspec0335, re0335)
mass_zphot_re0335 = gg.merge(zspec0335, re0335).query('~cPHOTID.isin(@mass_zspec_re0335.cPHOTID)')

ax[0,2].scatter(np.log10(mass_zspec_re0335.Mstellar.values), mass_zspec_re0335.re.values, c='red', label='Spectroscopic z')
ax[0,2].scatter(np.log10(mass_zphot_re0335.Mstellar.values), mass_zphot_re0335.re.values, c='blue', label='Photometric z')
ax[0,2].title.set_text('SPJ0335')

# SPJ1034
clusterZ = 1.38500
criteria = [
    'Star==0',
    'K_flag==0',
    'totmask==0',
    '(' + str(clusterZ-0.02) +  '< zspec.values <' + str(clusterZ+0.02) + ')',
    '(' + str(clusterZ-0.08) +  '< zphot.values <' + str(clusterZ+0.08) + ')'
]

zspec1034 = gg.search('SpARCS1034', targetProperties[0], criteria[:4], targetCatalogs[0])
zphot1034 = gg.search('SpARCS1034', targetProperties[0], criteria[:3] + criteria[-1:], targetCatalogs[0])
re1034 = gg.search('SPJ1034', targetProperties[1], ['re > 0'], targetCatalogs[1])
mass_zspec_re1034 = gg.merge(zspec1034, re1034)
mass_zphot_re1034 = gg.merge(zphot1034, re1034).query('~cPHOTID.isin(@mass_zspec_re1034.cPHOTID)')

ax[0,3].scatter(np.log10(mass_zspec_re1034.Mstellar.values), mass_zspec_re1034.re.values, c='red', label='Spectroscopic z')
ax[0,3].scatter(np.log10(mass_zphot_re1034.Mstellar.values), mass_zphot_re1034.re.values, c='blue', label='Photometric z')
ax[0,3].title.set_text('SPJ1034')

# SPJ1051
clusterZ = 1.03500
criteria = [
    'Star==0',
    'K_flag==0',
    'totmask==0',
    '(' + str(clusterZ-0.02) +  '< zspec.values <' + str(clusterZ+0.02) + ')',
    '(' + str(clusterZ-0.08) +  '< zphot.values <' + str(clusterZ+0.08) + ')'
]

zspec1051 = gg.search('SpARCS1051', targetProperties[0], criteria[:4], targetCatalogs[0])
zphot1051 = gg.search('SpARCS1051', targetProperties[0], criteria[:3] + criteria[-1:], targetCatalogs[0])
re1051 = gg.search('SPJ1051', targetProperties[1], ['re > 0'], targetCatalogs[1])
mass_zspec_re1051 = gg.merge(zspec1051, re1051)
mass_zphot_re1051 = gg.merge(zphot1051, re1051).query('~cPHOTID.isin(@mass_zspec_re1051.cPHOTID)')

ax[1,0].scatter(np.log10(mass_zspec_re1051.Mstellar.values), mass_zspec_re1051.re.values, c='red', label='Spectroscopic z')
ax[1,0].scatter(np.log10(mass_zphot_re1051.Mstellar.values), mass_zphot_re1051.re.values, c='blue', label='Photometric z')
ax[1,0].title.set_text('SPJ1051')

# SPJ1616
clusterZ = 1.15600
criteria = [
    'Star==0',
    'K_flag==0',
    'totmask==0',
    '(' + str(clusterZ-0.02) +  '< zspec.values <' + str(clusterZ+0.02) + ')',
    '(' + str(clusterZ-0.08) +  '< zphot.values <' + str(clusterZ+0.08) + ')'
]

zspec1616 = gg.search('SpARCS1616', targetProperties[0], criteria[:4], targetCatalogs[0])
zphot1616 = gg.search('SpARCS1616', targetProperties[0], criteria[:3] + criteria[-1:], targetCatalogs[0])
re1616 = gg.search('SPJ1616', targetProperties[1], ['re > 0'], targetCatalogs[1])
mass_zspec_re1616 = gg.merge(zspec1616, re1616)
mass_zphot_re1616 = gg.merge(zphot1616, re1616).query('~cPHOTID.isin(@mass_zspec_re1616.cPHOTID)')

ax[1,1].scatter(np.log10(mass_zspec_re1616.Mstellar.values), mass_zspec_re1616.re.values, c='red', label='Spectroscopic z')
ax[1,1].scatter(np.log10(mass_zphot_re1616.Mstellar.values), mass_zphot_re1616.re.values, c='blue', label='Photometric z')
ax[1,1].title.set_text('SPJ1616')

# SPJ1634
clusterZ = 1.17700
criteria = [
    'Star==0',
    'K_flag==0',
    'totmask==0',
    '(' + str(clusterZ-0.02) +  '< zspec.values <' + str(clusterZ+0.02) + ')',
    '(' + str(clusterZ-0.08) +  '< zphot.values <' + str(clusterZ+0.08) + ')'
]

zspec1634 = gg.search('SpARCS1634', targetProperties[0], criteria[:4], targetCatalogs[0])
zphot1634 = gg.search('SpARCS1634', targetProperties[0], criteria[:3] + criteria[-1:], targetCatalogs[0])
re1634 = gg.search('SPJ1634', targetProperties[1], ['re > 0'], targetCatalogs[1])
mass_zspec_re1634 = gg.merge(zspec1634, re1634)
mass_zphot_re1634 = gg.merge(zphot1634, re1634).query('~cPHOTID.isin(@mass_zspec_re1634.cPHOTID)')

ax[1,2].scatter(np.log10(mass_zspec_re1634.Mstellar.values), mass_zspec_re1634.re.values, c='red', label='Spectroscopic z')
ax[1,2].scatter(np.log10(mass_zphot_re1634.Mstellar.values), mass_zphot_re1634.re.values, c='blue', label='Photometric z')
ax[1,2].title.set_text('SPJ1634')

# SPJ1638
clusterZ = 1.19600
criteria = [
    'Star==0',
    'K_flag==0',
    'totmask==0',
    '(' + str(clusterZ-0.02) +  '< zspec.values <' + str(clusterZ+0.02) + ')',
    '(' + str(clusterZ-0.08) +  '< zphot.values <' + str(clusterZ+0.08) + ')'
]

zspec1638 = gg.search('SpARCS1638', targetProperties[0], criteria[:4], targetCatalogs[0])
zphot1638 = gg.search('SpARCS1638', targetProperties[0], criteria[:3] + criteria[-1:], targetCatalogs[0])
re1638 = gg.search('SPJ1638', targetProperties[1], ['re > 0'], targetCatalogs[1])
mass_zspec_re1638 = gg.merge(zspec1638, re1638)
mass_zphot_re1638 = gg.merge(zphot1638, re1638).query('~cPHOTID.isin(@mass_zspec_re1638.cPHOTID)')

ax[1,3].scatter(np.log10(mass_zspec_re1638.Mstellar.values), mass_zspec_re1638.re.values, c='red', label='Spectroscopic z')
ax[1,3].scatter(np.log10(mass_zphot_re1638.Mstellar.values), mass_zphot_re1638.re.values, c='blue', label='Photometric z')
ax[1,3].title.set_text('SPJ1638')

# SPT0205
clusterZ = 1.32270
criteria = [
    'Star==0',
    'K_flag==0',
    'totmask==0',
    '(' + str(clusterZ-0.02) +  '< zspec.values <' + str(clusterZ+0.02) + ')',
    '(' + str(clusterZ-0.08) +  '< zphot.values <' + str(clusterZ+0.08) + ')'
]

zspec0205 = gg.search('SPT0205', targetProperties[0], criteria[:4], targetCatalogs[0])
zphot0205 = gg.search('SPT0205', targetProperties[0], criteria[:3] + criteria[-1:], targetCatalogs[0])
re0205 = gg.search('SPT0205', targetProperties[1], ['re > 0'], targetCatalogs[1])
mass_zspec_re0205 = gg.merge(zspec0205, re0205)
mass_zphot_re0205 = gg.merge(zphot0205, re0205).query('~cPHOTID.isin(@mass_zspec_re0205.cPHOTID)')

ax[2,0].scatter(np.log10(mass_zspec_re0205.Mstellar.values), mass_zspec_re0205.re.values, c='red', label='Spectroscopic z')
ax[2,0].scatter(np.log10(mass_zphot_re0205.Mstellar.values), mass_zphot_re0205.re.values, c='blue', label='Photometric z')
ax[2,0].title.set_text('SPT0205')

# SPT0546
clusterZ = 1.06690
criteria = [
    'Star==0',
    'K_flag==0',
    'totmask==0',
    '(' + str(clusterZ-0.02) +  '< zspec.values <' + str(clusterZ+0.02) + ')',
    '(' + str(clusterZ-0.08) +  '< zphot.values <' + str(clusterZ+0.08) + ')'
]

zspec0546 = gg.search('SPT0546', targetProperties[0], criteria[:4], targetCatalogs[0])
zphot0546 = gg.search('SPT0546', targetProperties[0], criteria[:3] + criteria[-1:], targetCatalogs[0])
re0546 = gg.search('SPT0546', targetProperties[1], ['re > 0'], targetCatalogs[1])
mass_zspec_re0546 = gg.merge(zspec0546, re0546)
mass_zphot_re0546 = gg.merge(zphot0546, re0546).query('~cPHOTID.isin(@mass_zspec_re0546.cPHOTID)')

ax[2,1].scatter(np.log10(mass_zspec_re0546.Mstellar.values), mass_zspec_re0546.re.values, c='red', label='Spectroscopic z')
ax[2,1].scatter(np.log10(mass_zphot_re0546.Mstellar.values), mass_zphot_re0546.re.values, c='blue', label='Photometric z')
ax[2,1].title.set_text('SPT0546')

# SPT2106
clusterZ = 1.13066
criteria = [
    'Star==0',
    'K_flag==0',
    'totmask==0',
    '(' + str(clusterZ-0.02) +  '< zspec.values <' + str(clusterZ+0.02) + ')',
    '(' + str(clusterZ-0.08) +  '< zphot.values <' + str(clusterZ+0.08) + ')'
]

zspec2106 = gg.search('SPT2106', targetProperties[0], criteria[:4], targetCatalogs[0])
zphot2106 = gg.search('SPT2106', targetProperties[0], criteria[:3] + criteria[-1:], targetCatalogs[0])
re2106 = gg.search('SPT2106', targetProperties[1], ['re > 0'], targetCatalogs[1])
mass_zspec_re2106 = gg.merge(zspec2106, re2106)
mass_zphot_re2106 = gg.merge(zphot2106, re2106).query('~cPHOTID.isin(@mass_zspec_re2106.cPHOTID)')

ax[2,2].scatter(np.log10(mass_zspec_re2106.Mstellar.values), mass_zspec_re2106.re.values, c='red', label='Spectroscopic z')
ax[2,2].scatter(np.log10(mass_zphot_re2106.Mstellar.values), mass_zphot_re2106.re.values, c='blue', label='Photometric z')
ax[2,2].title.set_text('SPT2106')
# Out:
#         cPHOTID      Mstellar
# 6680  104001943  1.862087e+10
# 6750  104002029  7.079458e+10
# 6757  104002036  5.495409e+10
# 6828  104002121  1.230269e+10
# 6836  104002134  3.981072e+10
# 6902  104002211  3.890451e+10
# 6930  104002247  5.011872e+10
# 7008  104002339  3.090295e+10
# 7013  104002345  5.888437e+10
# 7041  104002381  6.606934e+09
# 7107  104002462  4.365158e+10
# 7190  104002558  2.818383e+09
# 7210  104002583  1.047129e+10
# 7218  104002592  1.122018e+10
# 7322  104002724  1.659587e+10
# 7402  104002818  4.168694e+10
# 7417  104002833  1.819701e+10
# 7433  104002850  3.548134e+10
# 7497  104002936  3.801894e+10
# 7561  104003022  5.011872e+09
# 7595  104003065  7.943282e+09
# 7877  104003436  2.951209e+09
# 8027  104003630  8.511380e+09
# 8635  104004447  1.737801e+10
# 8894  104004835  2.884032e+09
#       PHOTCATID        re
# 497         498  0.122307
# 500         501  0.392059
# 506         507  0.681839
# 521         522  0.018000
# 525         526  0.750707
# ...
